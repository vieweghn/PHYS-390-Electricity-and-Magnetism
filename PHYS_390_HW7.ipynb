# %% [markdown]
# <a href="https://colab.research.google.com/github/vieweghn/PHYS-390-Electricity-and-Magnetism/blob/main/PHYS_390_HW7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# I is momentarily clockwise when the switch is closed. It's momentarily counter clockwise when the switch is open. Bonus: Think of a strategy to compute the actual time dependence numerically. What would you have to do?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# a) $V_\mathrm{emf} = 6.9 \times 10^{-3} \sin(2\pi \times 10^4 t)$ V\
# b) $I = 1.38\sin(2\pi \times 10^4 t)\ \mathrm{mA}$\
# At $t=0$ the current is clockwise.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# a) $V_\mathrm{emf} = \frac{\mu c N \omega I_0}{2\pi}\ln\left(\frac{b}{a}\right) \sin \omega t $ \
# b) $V_\mathrm{emf} = 5.5 \sin(377t)\ \mathrm{V}$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $I_2 = 150\left(\frac{1}{y_0} - \frac{1}{y_0 + 0.1}\right)\ \mathrm{nA}$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
Er = 4
E = 8.85e-12
sigma = 2.5
A = 4e-4
d = .5e-2
coef_cap = Er*E*A/d
coef_cap
# Out:
# 2.832e-12

# %%
R = d / (sigma*A)
R
# Out:
# 5.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# a) $I_\mathrm{c} = \frac{V \sigma A}{d}$\
# b) $I_\mathrm{d} = \frac{\epsilon A}{d}\frac{\partial V}{\partial t}$\
# c) The equivalent circuit is a parallel combination of ideal components.\
# d) $C = 2.84\ \mathrm{pF}$
