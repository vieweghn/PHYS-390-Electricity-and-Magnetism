# %% [markdown]
# <a href="https://colab.research.google.com/github/vieweghn/PHYS-390-Electricity-and-Magnetism/blob/main/PHYS_390_HW8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# a) 10m, b) 36, 62.83Ω

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $|E| = 30\,\mathrm{V/m}$, $\psi = 0, -\frac{\pi}{4}, -\frac{\pi}{2}$ at t=0, 5ns, and 10ns, respectively.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ex(t=0) = 0, Ey(t=0)=2\
# Ex(t=pi/2) = 1, Ey(t=pi/2)=0\
# Polarization is RHE

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# a) $\frac{1}{2}\sigma\,E_0^2\times 10^{-9}\,\mathrm{W/mm^2}$\
# b) $0.8\,\mathrm{W/mm^2}$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# a) 25\
# b) $8.2\times 10^{-4}\Omega$\
# c) $0.039\,\Omega/m$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $f \le 41.6\,\mathrm{MHz}$
